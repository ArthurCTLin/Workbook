# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurCTLin/Workbook/blob/main/Introduction%20to%20Numerical%20Analysis/Lecture304_hw_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Connect to TPU
# * Edit -> NoteBook settings
# * Select TPU from the Hardware Accelerator drop-down
# * Run the following script to check the connect situation

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.4.1
# Running on TPU  ['10.36.133.26:8470']
# INFO:tensorflow:Initializing the TPU system: grpc://10.36.133.26:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.36.133.26:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# ### Connect to google drive for loading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/ColabNotebooks/"
# Out:
# font_data.npy  l304practice.npz  Lecture304_practice01.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow_datasets as tfds

data = np.load('/content/drive/MyDrive/ColabNotebooks/l304practice.npz')
x_train = data['x_train']
y_train = np.array([np.eye(2)[n-1] for n in data['y_train']])
x_test = data['x_test']
y_test = np.array([np.eye(2)[n-1] for n in data['y_test']])

from keras.models import Sequential
from keras.layers import *
from keras.optimizers import Adadelta

model = Sequential()
model.add(Reshape((48,48,1), input_shape=(48,48)))
model.add(Conv2D(16, kernel_size=(5,5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=50, batch_size=32,
          validation_data=(x_test, y_test))

print('Performance (training)')
print('Loss: %.5f, Acc: %.5f' % tuple(model.evaluate(x_train, y_train)))
print('Performance (testing)')
print('Loss: %.5f, Acc: %.5f' % tuple(model.evaluate(x_test, y_test)))

p_test = model.predict(x_test)
failedsample = [[img,y,p] for img,y,p in zip(data['x_test'],y_test,p_test) if y.argmax()!=p.argmax()]
print('# of failed test samples:',len(failedsample))

fig = plt.figure(figsize=(10,10), dpi=80)
for i in range(len(failedsample[:100])):
    plt.subplot(10,10,i+1)
    plt.axis('off')
    plt.imshow(failedsample[i][0], cmap='Greys')
    plt.text(0.,0.,'$%d\\to%d$' % (failedsample[i][1].argmax()+1,failedsample[i][2].argmax()+1),color='Red',fontsize=15)
plt.show()
# Out:
# Epoch 1/50
# 200/200 [==============================] - 5s 21ms/step - loss: 23.7751 - accuracy: 0.4818 - val_loss: 15.6885 - val_accuracy: 0.5227
# Epoch 2/50
# 200/200 [==============================] - 4s 20ms/step - loss: 20.2058 - accuracy: 0.5251 - val_loss: 13.1182 - val_accuracy: 0.5734
# Epoch 3/50
# 200/200 [==============================] - 4s 19ms/step - loss: 18.1468 - accuracy: 0.5610 - val_loss: 11.2013 - val_accuracy: 0.6216
# Epoch 4/50
# 200/200 [==============================] - 4s 19ms/step - loss: 15.4565 - accuracy: 0.5858 - val_loss: 9.6722 - val_accuracy: 0.6598
# Epoch 5/50
# 200/200 [==============================] - 4s 19ms/step - loss: 14.0866 - accuracy: 0.6286 - val_loss: 8.4708 - val_accuracy: 0.6903
# Epoch 6/50
# 200/200 [==============================] - 4s 20ms/step - loss: 13.3632 - accuracy: 0.6433 - val_loss: 7.4047 - val_accuracy: 0.7198
# Epoch 7/50
# 200/200 [==============================] - 4s 20ms/step - loss: 11.5732 - accuracy: 0.6736 - val_loss: 6.5734 - val_accuracy: 0.7500
# Epoch 8/50
# 200/200 [==============================] - 4s 19ms/step - loss: 10.8991 - accuracy: 0.6872 - val_loss: 5.8742 - val_accuracy: 0.7736
# Epoch 9/50
# 200/200 [==============================] - 4s 20ms/step - loss: 9.9572 - accuracy: 0.7121 - val_loss: 5.2871 - val_accuracy: 0.7935
# Epoch 10/50
# 200/200 [==============================] - 4s 19ms/step - loss: 8.8092 - accuracy: 0.7301 - val_loss: 4.7862 - val_accuracy: 0.8119
# Epoch 11/50
# 200/200 [==============================] - 4s 20ms/step - loss: 9.3433 - accuracy: 0.7303 - val_loss: 4.3443 - val_accuracy: 0.8284
# Epoch 12/50
# 200/200 [==============================] - 4s 19ms/step - loss: 8.3003 - accuracy: 0.7462 - val_loss: 3.9608 - val_accuracy: 0.8408
# Epoch 13/50
# 200/200 [==============================] - 4s 19ms/step - loss: 7.0351 - accuracy: 0.7746 - val_loss: 3.6322 - val_accuracy: 0.8520
# Epoch 14/50
# 200/200 [==============================] - 4s 20ms/step - loss: 6.6240 - accuracy: 0.7835 - val_loss: 3.3543 - val_accuracy: 0.8616
# Epoch 15/50
# 200/200 [==============================] - 4s 20ms/step - loss: 6.4247 - accuracy: 0.7964 - val_loss: 3.1025 - val_accuracy: 0.8710
# Epoch 16/50
# 200/200 [==============================] - 4s 20ms/step - loss: 6.2314 - accuracy: 0.7962 - val_loss: 2.8791 - val_accuracy: 0.8781
# Epoch 17/50
# 200/200 [==============================] - 4s 20ms/step - loss: 5.3247 - accuracy: 0.8218 - val_loss: 2.6808 - val_accuracy: 0.8859
# Epoch 18/50
# 200/200 [==============================] - 4s 20ms/step - loss: 5.2397 - accuracy: 0.8262 - val_loss: 2.5026 - val_accuracy: 0.8933
# Epoch 19/50
# 200/200 [==============================] - 4s 20ms/step - loss: 4.9272 - accuracy: 0.8263 - val_loss: 2.3341 - val_accuracy: 0.8980
# Epoch 20/50
# 200/200 [==============================] - 4s 20ms/step - loss: 4.8313 - accuracy: 0.8301 - val_loss: 2.1833 - val_accuracy: 0.9036
# Epoch 21/50
# 200/200 [==============================] - 4s 19ms/step - loss: 4.5599 - accuracy: 0.8427 - val_loss: 2.0490 - val_accuracy: 0.9092
# Epoch 22/50
# 200/200 [==============================] - 4s 19ms/step - loss: 4.1514 - accuracy: 0.8517 - val_loss: 1.9381 - val_accuracy: 0.9123
# Epoch 23/50
# 200/200 [==============================] - 4s 20ms/step - loss: 4.2398 - accuracy: 0.8572 - val_loss: 1.8158 - val_accuracy: 0.9160
# Epoch 24/50
# 200/200 [==============================] - 4s 20ms/step - loss: 3.5594 - accuracy: 0.8653 - val_loss: 1.7155 - val_accuracy: 0.9198
# Epoch 25/50
# 200/200 [==============================] - 4s 20ms/step - loss: 3.5651 - accuracy: 0.8697 - val_loss: 1.6238 - val_accuracy: 0.9220
# Epoch 26/50
# 200/200 [==============================] - 4s 21ms/step - loss: 3.7393 - accuracy: 0.8631 - val_loss: 1.5339 - val_accuracy: 0.9275
# Epoch 27/50
# 200/200 [==============================] - 4s 20ms/step - loss: 3.3509 - accuracy: 0.8731 - val_loss: 1.4572 - val_accuracy: 0.9294
# Epoch 28/50
# 200/200 [==============================] - 4s 20ms/step - loss: 3.4015 - accuracy: 0.8834 - val_loss: 1.3836 - val_accuracy: 0.9331
# Epoch 29/50
# 200/200 [==============================] - 3s 17ms/step - loss: 3.1853 - accuracy: 0.8830 - val_loss: 1.3137 - val_accuracy: 0.9347
# Epoch 30/50
# 200/200 [==============================] - 4s 19ms/step - loss: 3.2626 - accuracy: 0.8822 - val_loss: 1.2473 - val_accuracy: 0.9375
# Epoch 31/50
# 200/200 [==============================] - 4s 20ms/step - loss: 3.0075 - accuracy: 0.8872 - val_loss: 1.1882 - val_accuracy: 0.9403
# Epoch 32/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.8842 - accuracy: 0.8891 - val_loss: 1.1291 - val_accuracy: 0.9419
# Epoch 33/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.7233 - accuracy: 0.8951 - val_loss: 1.0798 - val_accuracy: 0.9434
# Epoch 34/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.7154 - accuracy: 0.8895 - val_loss: 1.0320 - val_accuracy: 0.9462
# Epoch 35/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.6376 - accuracy: 0.9029 - val_loss: 0.9903 - val_accuracy: 0.9468
# Epoch 36/50
# 200/200 [==============================] - 4s 19ms/step - loss: 2.3573 - accuracy: 0.9040 - val_loss: 0.9495 - val_accuracy: 0.9484
# Epoch 37/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.0720 - accuracy: 0.9142 - val_loss: 0.9046 - val_accuracy: 0.9515
# Epoch 38/50
# 200/200 [==============================] - 3s 17ms/step - loss: 2.3385 - accuracy: 0.9061 - val_loss: 0.8655 - val_accuracy: 0.9524
# Epoch 39/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.1533 - accuracy: 0.9138 - val_loss: 0.8350 - val_accuracy: 0.9549
# Epoch 40/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.2452 - accuracy: 0.9106 - val_loss: 0.8133 - val_accuracy: 0.9546
# Epoch 41/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.3237 - accuracy: 0.9091 - val_loss: 0.7769 - val_accuracy: 0.9574
# Epoch 42/50
# 200/200 [==============================] - 4s 20ms/step - loss: 2.0208 - accuracy: 0.9169 - val_loss: 0.7508 - val_accuracy: 0.9583
# Epoch 43/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.9057 - accuracy: 0.9243 - val_loss: 0.7262 - val_accuracy: 0.9596
# Epoch 44/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.8887 - accuracy: 0.9152 - val_loss: 0.7038 - val_accuracy: 0.9599
# Epoch 45/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.7255 - accuracy: 0.9277 - val_loss: 0.6826 - val_accuracy: 0.9608
# Epoch 46/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.9770 - accuracy: 0.9166 - val_loss: 0.6680 - val_accuracy: 0.9605
# Epoch 47/50
# 200/200 [==============================] - 4s 19ms/step - loss: 1.8193 - accuracy: 0.9250 - val_loss: 0.6428 - val_accuracy: 0.9621
# Epoch 48/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.7819 - accuracy: 0.9237 - val_loss: 0.6181 - val_accuracy: 0.9630
# Epoch 49/50
# 200/200 [==============================] - 4s 19ms/step - loss: 1.7302 - accuracy: 0.9288 - val_loss: 0.5976 - val_accuracy: 0.9639
# Epoch 50/50
# 200/200 [==============================] - 4s 20ms/step - loss: 1.6762 - accuracy: 0.9244 - val_loss: 0.5801 - val_accuracy: 0.9652
# Performance (training)
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5163 - accuracy: 0.9686
# Loss: 0.51626, Acc: 0.96859
# Performance (testing)
# 101/101 [==============================] - 1s 11ms/step - loss: 0.5801 - accuracy: 0.9652
# Loss: 0.58005, Acc: 0.96517
# # of failed test samples: 112
